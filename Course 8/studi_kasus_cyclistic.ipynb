# %% [markdown]
# # Meningkatkan Revenue Cyclistic Melalui *Casual Members*
#
# ---

# %% [markdown]
# ### Latar Belakang Kasus

# %% [markdown]
# Sebagai seorang analis data yang bekerja dalam tim pemasaran di Cyclistic (sebuah perusahaan bike-sharing yang aktif di Chicago), saya mendapatkan tugas untuk memahami bagaimana pengendara casual (*casual riders*) dan pengendara tahunan (*annual members*) menggunakan sepeda Cyclistic secara berbeda.
#
# Mereka yang membeli tiket sekali jalan atau tiket sehari penuh disebut ***casual riders***. Sedangkan mereka yang membeli keanggotaan tahunan disebut ***annual members***.
#
# Analis keuangan Cyclistic telah menyimpulkan bahwa *annual members* jauh lebih menguntungkan daripada *casual riders*.
#
# Direktur pemasaran memiliki teori bahwa memaksimalkan jumlah *annual members* akan menjadi kunci pertumbuhan dimasa depan daripada membuat kampanye pemasaran yang menargetkan *casual riders* baru. Direktur pemasaran percaya bahwa ada peluang untuk mengubah *casual members* menjadi *annual members*.

# %% [markdown]
# ### Lingkup Kerja

# %% [markdown]
# | <center><b>Proses Analisis Data</b></center>                                                   | <center><b>Tugas</b></center>                                                                                                                                                                                                                                                                                                                                                                                              |
# | ---------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | <center> <b>Bertanya</b> <br> (Mendefinisikan dan mendiskusikan proyek) </center>              | <ol><li>Membuat dokumen lingkup kerja</li><li>Membuat bingkai pernyataan masalah</li><li>Mendefinisikan tujuan proyek dan pengukuran untuk menentukan keberhasilan bisnis dengan berdiskusi bersama <i>stakeholders</i></li></ol>                                                                                                                                                                                          |
# | <center> <b>Mempersiapkan</b> <br> (Ekstrak dan mempersiapkan data untuk eksplorasi) </center> | <ol><li>Identifikasi keberadaan data beserta struktur datanya</li><li>Menentukan <i>ROCCC (Reliability, Origins, Comprehensiveness, Current relevance, and Credibility)</i></li><li>Menangani perizinan, privasi, keamanan, dan aksesibilitas data</li><li>Melakukan verifikasi integritas data</li><li>Identifikasi bagaimana data dapat menjawab pertanyaan analisis data</li><li>Memfilter dan menyortir data</li></ol> |
# | <center> <b>Memproses</b> <br> (Memproses data untuk analisis) </center>                       | <ol><li>Menggunakan alat manipulasi data yang benar untuk pemrosesan dan analisis data</li><li>Pengecekan data kotor (data usang, duplikat, tidak lengkap, tidak konsisten, dan tidak akurat)</li><li>Membersihkan data</li></ol>                                                                                                                                                                                          |
# | <center> <b>Menganalisis</b> <br> (Melakukan analisis deskriptif) </center>                    | <ol><li>Mengatur dan memformat data</li><li>Mengidentifikasi tren dan hubungan tiap variabel dalam data</li><li>Memberikan ringkasan dari analisis</li></ol>                                                                                                                                                                                                                                                               |
# | <center> <b>Berbagi</b> <br> (Membagikan temuan utama kepada stakeholders) </center>           | Membuat presentasi yang menjawab permasalahan bisnis dengan penceritaan yang menarik                                                                                                                                                                                                                                                                                                                                       |
# | <center> <b>Bertindak</b> <br> (Tindakan berdasarkan temuan utama) </center>                   | Berdasarkan analisis yang dilakukan, berikan beberapa rekomendasi kepada tim pemasaran untuk kemajuan bisnis                                                                                                                                                                                                                                                                                                               |

# %% [markdown]
# ## Bertanya

# %% [markdown]
# ### Latar Belakang Bisnis

# %% [markdown]
# **Model Bisnis:**
#
# * Bisnis *bike-sharing* yang terletak di Chicago
# * Terdapat dua tipe pelanggan:
#   * *Casual Members* (Penyewaan sekali pakai atau sehari penuh)
#   * *Annual Members* (Penyewaan tahunan)
# * Keunggulan Kompetitif:
#   * Segmentasi pelanggan yang luas
#   * Fleksibilitas harga
#
# **Latar Belakang Produk:**
#
# * 5.824 sepeda dan 692 stasiun
# * Pengguna cenderung bersepeda untuk bersantai, sekitar 30% menggunakan sepeda untuk bepergian ke tempat kerja

# %% [markdown]
# ### Diskusi Harapan dan Tujuan

# %% [markdown]
# | <center><b>Stakeholders</b></center>                            | <center><b>Harapan</b></center>                                                                   | <center><b>Tujuan Bisnis</b></center>                                                                                    |
# | --------------------------------------------------------------- | ------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------ |
# | <center> <b>Lily Moreno</b> <br> (Direktur Pemasaran) </center> | Bukti pendukukung teorinya dan rekomendasi pemasaran                                              | Memaksimalkan jumlah *annual members*                                                                                    |
# | <center> <b>Tim Analitik Pemasaran</b>                          | Mengungkap perbedaan dan motivasi dibalik tipe *casual members* dan *annual members*                             | Menghasilkan hasil yang didasari oleh data dan dapat ditindaklanjuti untuk menginformasikan pengambilan keputusan bisnis |
# | <center> <b>Tim Eksekutif</b> </center>                         | Wawasan yang menarik, mudah, dan relevan untuk menginformasikan keputusan pemasaran berbasis data | Menerapkan inisiatif strategi untuk mendorong pertumbuhan bisnis                                                         |

# %% [markdown]
# ### Pernyataaan Masalah

# %% [markdown]
# Cyclistic dihadapkan pada masa depan yang tidak jelas dan tidak bisa mengandalkan strategi pemasaran bisnis secara tradisional. Direktur pemasaran percaya bahwa Cyclistic dapat memanfaatkan margin keuntungan dari pelanggan tahunan dengan membujuk *casual members* untuk menjadi *annual members*. Jika strategi bisnis ini masuk akal dan berhasil diimplementasikan, pendapatan perusahaan jangka panjang akan meningkat secara berkelanjutan. Oleh karena itu, perlu melakukan analisis perbedaan yang terdapat pada *casual members* dan *annual members* untuk menetapkan strategi pemasaran yang cocok dimasa depan.

# %% [markdown]
# ## Mempersiapkan

# %% [markdown]
# ### Lingkup Prapemrosesan

# %% [markdown]
# 1. Memilih dataset, menelusuri lokasi data dan bagaimana data diatur
# 2. Pengecekan standarisasi data berdasarkan ROCCC (Reliable, Original, Comprehensive, Current, and Credible)
# 3. Mengatasi masalah etika data (keamanan, aksesibilitas, privasi, dan lisensi)
# 4. Melakukan verifikasi integritas data
# 5. Identifikasi bagaimana data membantu menjawab pertanyaan bisnis
# 6. Memfilter dan menyortir data

# %% [markdown]
# ### Sumber Data dan Organisasi

# %% [markdown]
# Data yang kita gunakan dalam analisis ini diekstrak dari [sini](https://divvy-tripdata.s3.amazonaws.com/index.html). Data ini disediakan oleh Divvy dibawah [lisensi berikut](https://www.divvybikes.com/data-license-agreement).
#
# *Catatan: Cyclistic merupakan perusahaan fiksi dan data dari Divvy digunakan dengan tujuan studi kasus ini.*
#
# Data tersedia dalam bentuk repositori yang dikumpulkan dari waktu ke waktu. Tiap poin data merepresentasikan perjalanan sepeda dari satu stasiun ke stasiun berikutnya.
#
# Kami akan bekerja pada data dalam periode 12 bulan terakhir, yaitu dari 01 Oktober 2021 sampai 30 September 2022.

# %% [markdown]
# ### Penilaian Kualitas Data

# %% [markdown]
# | <center><b><i>ROCCC</i></b></center>  | <center><b>Status</b></center> | <center><b>Deskripsi</b></center>                                                                                                                                                                                                                                    |
# | ------------------------------------- | ------------------------------ | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | <center><i>Reliable</i></center>      | ⚠️                           | <b>Validitas</b> <br>Kolom start_station_id dan end_station_id memiliki format yang kurang konsisten <br><br><b>Kelengkapan</b><br>Terdapat 0.1% nilai yang hilang (*null values*)<br><br><b>Duplikat</b><br>Semua nilai pada kolom ride_id memiliki nilai yang unik |
# | <center><i>Original</i></center>      | ✅                             | Data bersumber dari pihak pertama                                                                                                                                                                                                                                    |
# | <center><i>Comprehensive</i></center> | ✅                             | Data cukup lengkap dan sebagian besar bebas dari kesalahan manusia                                                                                                                                                                                                   |
# | <center><i>Current</i></center>       | ✅                             | Data memberi kami pandangan tentang perjalanan terkini (sejak catatan ini ditulis)                                                                                                                                                                                   |
# | <center><i>Cited</i></center>         | ✅                             | Data dikutip dari pihak pertama secara langsung sehingga data memiliki kredibilitas yang cukup baik                                                                                                                                                                  |

# %% [markdown]
# ### Etika Data

# %% [markdown]
# **Keamanan**
#
# Data disimpan dalam *cloud repository* yang diamankan oleh penyedia layanan *cloud* yang terpercaya.
#
# **Aksesibilitas**
#
# Data perjalanan sepeda dari Cyclistic dapat diakses secara publik.
#
# **Privasi**
#
# Data telah terbebas dari informasi pengenal pribadi apapun.
#
# **Lisensi**
#
# Data berada dibawah [lisensi berikut](https://www.divvybikes.com/data-license-agreement).

# %% [markdown]
# ### Integritas Data

# %% [markdown]
# Data memiliki format yang sesuai pada setiap kolomnya. Terdapat beberapa nilai yang hilang, tetapi secara umum hal tersebut tidak menurunkan akurasi dan konsistensi data.

# %% [markdown]
# ### Tujuan Data

# %% [markdown]
# Data dikumpulkan dan dianalisis untuk menemukan pola dan wawasan yang dapat ditindaklanjuti dari tipe pengguna Cyclistic yang berbeda.

# %% [markdown]
# ### Penyaringan dan Penyortiran Data

# %% [markdown]
# Data telah difilter dan disortir berdasarkan tanggal dari 01 Oktober 2021 sampai 30 September 2022.

# %% [markdown]
# ## Memproses

# %% [markdown]
# ### Setting Google Drive Mount

# %%
# if (!require(googledrive)) install.packages("googledrive")
# if (!require(httpuv)) install.packages("httpuv")
# library("googledrive")
# library("httpuv")

# %%
# if (file.exists("/usr/local/lib/python3.7/dist-packages/google/colab/_ipython.py")) { #may need to update python version occasionally
#   if (!require(R.utils)) install.packages("R.utils")
#   library("R.utils")
#   library("httr")
#   my_check <- function() {return(TRUE)}
#   reassignInPackage("is_interactive", pkgName = "httr", my_check) 
#   options(rlang_interactive=TRUE)
# }

# %%
# drive_auth(use_oob = TRUE, cache = FALSE)

# %% [markdown]
# ### Import library R yang diperlukan

# %%
install.packages("tidyverse")
library(tidyverse)
library(data.table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 install.packages("tidyverse")
#       2 library(tidyverse)
#       3 library(data.table)
#
# NameError: name 'install' is not defined

# %% [markdown]
# ### Download Dataset

# %%
# Download file from Google Drive
list_file <- c("202110-divvy-tripdata.csv",
               "202111-divvy-tripdata.csv",
               "202112-divvy-tripdata.csv",
               "202201-divvy-tripdata.csv",
               "202202-divvy-tripdata.csv",
               "202203-divvy-tripdata.csv",
               "202204-divvy-tripdata.csv",
               "202205-divvy-tripdata.csv",
               "202206-divvy-tripdata.csv",
               "202207-divvy-tripdata.csv",
               "202208-divvy-tripdata.csv",
               "202209-divvy-publictripdata.csv")

for (i in list_file){
  x <- drive_get(paste0("~/Data Portfolio/unzip_csv/",i))
  if (file.exists(paste0("/content/",i))){
    next
  }
  drive_download(x)
}

z <- read_csv("/content/202110-divvy-tripdata.csv")
# Out:
# → Files retrieved so far: 100
#
# → Files retrieved so far: 200
#
# ✔ The input `path` resolved to exactly 1 file.
#
#
#
#
#
# → Files retrieved so far: 100
#
# → Files retrieved so far: 200
#
# ✔ The input `path` resolved to exactly 1 file.
#
#
#
#
#
# → Files retrieved so far: 100
#
# → Files retrieved so far: 200
#
# ✔ The input `path` resolved to exactly 1 file.
#
#
#
#
#
# → Files retrieved so far: 100
#
# → Files retrieved so far: 200
#
# ✔ The input `path` resolved to exactly 1 file.
#
#
#
#
#
# → Files retrieved so far: 100
#
# → Files retrieved so far: 200
#
# ✔ The input `path` resolved to exactly 1 file.
#
#
#
#
#
# → Files retrieved so far: 100
#
# → Files retrieved so far: 200
#
# ✔ The input `path` resolved to exactly 1 file.
#
#
#
#
#
# → Files retrieved so far: 100
#
# → Files retrieved so far: 200
#
# ✔ The input `path` resolved to exactly 1 file.
#
#
#
#
#
# → Files retrieved so far: 100
#
# → Files retrieved so far: 200
#
# ...

# %% [markdown]
# ### Cek konsistensi nama kolom pada masing-masing dataset

# %%
list_file <- list.files(path="/content/")
list_file <- list_file[!list_file=="sample_data"]
col_names <- NULL
for (i in list_file){
    name <- fread(paste0("/content/",i)) %>% colnames()
    col_names <- rbind(col_names,name)
}
# nrow() unique
check <- col_names %>% as.data.frame() %>%
    duplicated() %>%
    sum()
if (check==11){
    paste0("Setiap kolom pada masing-masing dataset memiliki nama yang sama.")
} else {
    paste0("Terdapat nama kolom yang berbeda pada masing-masing dataset.")
}
# Out:
# [1] "Setiap kolom pada masing-masing dataset memiliki nama yang sama."

# %% [markdown]
# ### Import dan menggabungkan dataset dari masing-masing dataset

# %%
list_file <- list.files(path="/content/")
list_file <- list_file[!list_file=="sample_data"]
divvy <- NULL
for (i in list_file){
    data <- fread(paste0("/content/",i), na.strings = c("",NA))
    divvy <- rbind(divvy,data)
}
print("Import dataset selesai.")
# Out:
# [1] "Import dataset selesai."

# %% [markdown]
# ### Melihat 6 baris pertama dataset

# %%
head(divvy)
# Out:
#   ride_id          rideable_type started_at          ended_at
# 1 620BC6107255BF4C electric_bike 2021-10-22 12:46:42 2021-10-22 12:49:50
# 2 4471C70731AB2E45 electric_bike 2021-10-21 09:12:37 2021-10-21 09:14:14
# 3 26CA69D43D15EE14 electric_bike 2021-10-16 16:28:39 2021-10-16 16:36:26
# 4 362947F0437E1514 electric_bike 2021-10-16 16:17:48 2021-10-16 16:19:03
# 5 BB731DE2F2EC51C5 electric_bike 2021-10-20 23:17:54 2021-10-20 23:26:10
# 6 7176307BBC097313 electric_bike 2021-10-21 16:57:37 2021-10-21 17:11:58
#   start_station_name       start_station_id end_station_name end_station_id
# 1 Kingsbury St & Kinzie St KA1503000043     NA               NA
# 2 NA                       NA               NA               NA
# 3 NA                       NA               NA               NA
# 4 NA                       NA               NA               NA
# 5 NA                       NA               NA               NA
# 6 NA                       NA               NA               NA
# ...

# %% [markdown]
# ### Cek *missing value, data type, unique value* dan *data summary* tiap kolom pada dataset

# %%
# Define check_missing_value function
check_missing_value <- function(my_table){
    col_names <- my_table %>% summarise(across(everything(), ~ sum(is.na(.)))) %>% colnames()
    missing_value <- my_table %>% summarise(across(everything(), ~ sum(is.na(.)))) 
    value <- NULL
    for (i in 1:length(col_names)){
        value <- append(value, missing_value[,i])
    }
    data.frame("column_name" = col_names,
               "missing_value"=value,
               "missing_rate_percent"=round((value/nrow(my_table))*100,2)
               )
}

check_missing_value(divvy)
# Out:
#    column_name        missing_value missing_rate_percent
# 1  ride_id                 0         0.00
# 2  rideable_type           0         0.00
# 3  started_at              0         0.00
# 4  ended_at                0         0.00
# 5  start_station_name 895032        15.36
# 6  start_station_id   895032        15.36
# 7  end_station_name   958227        16.44
# 8  end_station_id     958227        16.44
# 9  start_lat               0         0.00
# 10 start_lng               0         0.00
# 11 end_lat              5844         0.10
# 12 end_lng              5844         0.10
# 13 member_casual           0         0.00

# %% [markdown]
# Terdapat 16% missing values pada kolom `start_station_name`, `start_station_id`,`end_station_name`, `end_station_id`.

# %% [markdown]
# ### Cek konsistensi kolom `started_at` dan `ended_at`

# %%
length_trip_s <- difftime(divvy[,ended_at],divvy[,started_at])
divvy[,length_trip_s:=length_trip_s]
divvy[length_trip_s<=0,list(length_trip_s)] %>% head()
inconsistent_rows <- divvy[length_trip_s<=0,list(length_trip_s)] %>% nrow()
paste0("Terdapat baris yang tidak konsisten yaitu perjalanan yang memiliki durasi 0 detik bahkan berhilai negatif.")
paste0("Jumlah baris yang tidak konsisten antara kolom started_at dengan ended_at: ",inconsistent_rows)

divvy <- divvy[length_trip_s>0]
paste0("Baris yang kurang konsisten telah dihilangkan")
# Out:
#   length_trip_s
# 1 0 secs
# 2 0 secs
# 3 0 secs
# 4 0 secs
# 5 0 secs
# 6 0 secs
# [1] "Terdapat baris yang tidak konsisten yaitu perjalanan yang memiliki durasi 0 detik bahkan berhilai negatif."
# [1] "Jumlah baris yang tidak konsisten antara kolom started_at dengan ended_at: 571"
# [1] "Baris yang kurang konsisten telah dihilangkan"

# %% [markdown]
# ### Cek konsistensi kolom `start_station_id`, `start_station_name`, `end_station_id`, `end_station_name`

# %%
start_station <- divvy[,c("start_station_id","start_station_name")]
colnames(start_station) <- c("station_id","station_name")
end_station <- divvy[,c("end_station_id","end_station_name")]
colnames(end_station) <- c("station_id","station_name")
station <- rbindlist(list(start_station, end_station)) %>% unique()
station[,total_station_name:=c(.N),by="station_id"]
station[,total_station_id:=c(.N),by="station_name"]
station_id_count <- station[,c("station_id","total_station_name")]
station_name_count <- station[,c("station_name","total_station_id")]

station_id_count[total_station_name>1] %>% head()
station_name_count[total_station_id>1] %>% head()

inconsistent_station_id <- station_id_count[total_station_name>1] %>% nrow()
inconsistent_station_name <- station_name_count[total_station_id>1] %>% nrow()
paste0("Ada ",inconsistent_station_id," station_id yang memiliki station_name lebih dari satu.")
paste0("Ada ",inconsistent_station_name," station_name yang memiliki station_id lebih dari satu.")
# Out:
#   station_id total_station_name
# 1 604        3
# 2 653        2
# 3 657        3
# 4 523        3
# 5 632        2
# 6 546        3
#   station_name                    total_station_id
# 1 California Ave & Cortez St      2
# 2 Lakefront Trail & Bryn Mawr Ave 2
# 3 Christiana Ave & Lawrence Ave   2
# 4 Prairie Ave & Garfield Blvd     2
# 5 Wabash Ave & 87th St            2
# 6 East End Ave & 87th St          2
# [1] "Ada 623 station_id yang memiliki station_name lebih dari satu."
# [1] "Ada 38 station_name yang memiliki station_id lebih dari satu."

# %% [markdown]
# ### Dataset *Station Information*

# %% [markdown]
# Karena kolom `station_id` dan `station_name` tidak konsisten, maka kami memutuskan untuk menggunakan dataset station information agar kolom `station_id` dan `station_name` lebih konsisten.
#
# Dataset ini merupakan data internal *Divvy* yang dapat diakses secara publik di [link berikut](https://gbfs.divvybikes.com/gbfs/en/station_information.json).

# %%
library(jsonlite)

data <- fromJSON("https://gbfs.divvybikes.com/gbfs/en/station_information.json")

station <- data.table(
  station_id=data[["data"]][["stations"]][["station_id"]],
  name=data[["data"]][["stations"]][["name"]],
  lat=data[["data"]][["stations"]][["lat"]],
  lon=data[["data"]][["stations"]][["lon"]],
  short_name=data[["data"]][["stations"]][["short_name"]],
  capacity=data[["data"]][["stations"]][["capacity"]]
)
station %>% head()
# Out:
#   station_id                           name                           lat
# 1 a3b419d9-a135-11e9-9cda-0a87ae2ba916 Wood St & Chicago Ave          41.89563
# 2 a3aa8ca0-a135-11e9-9cda-0a87ae2ba916 Southport Ave & Irving Park Rd 41.95418
# 3 a3b2862e-a135-11e9-9cda-0a87ae2ba916 Bennett Ave & 79th St          41.75178
# 4 a3a41004-a135-11e9-9cda-0a87ae2ba916 Cannon Dr & Fullerton Ave      41.92676
# 5 a3a52df5-a135-11e9-9cda-0a87ae2ba916 Desplaines St & Randolph St    41.88462
# 6 a3ad95a7-a135-11e9-9cda-0a87ae2ba916 Cottage Grove Ave & 63rd St    41.78053
#   lon       short_name   capacity
# 1 -87.67207 637          15
# 2 -87.66436 TA1309000043 15
# 3 -87.57850 16970        11
# 4 -87.63443 13124        15
# 5 -87.64457 15535        23
# 6 -87.60597 KA1503000054 15

# %%
# covert latitude and longitude to 5 digit decimal
divvy[,start_lat:=(divvy[,start_lat] %>% round(5))]
divvy[,start_lng:=(divvy[,start_lng] %>% round(5))]
divvy[,end_lat:=(divvy[,end_lat] %>% round(5))]
divvy[,end_lng:=(divvy[,end_lng] %>% round(5))]

# %%
# Left Join divvy with station to get more detail station_name
divvy <- merge(divvy, station[!is.na(short_name)], by.x="start_station_id", by.y="short_name", all.x=TRUE)
divvy[,start_station_name:=fcoalesce(divvy[,name],divvy[,start_station_name])]
divvy <- divvy[,-c("station_id","name","lat","lon","capacity")]
divvy <- merge(divvy, station[!is.na(short_name)], by.x="end_station_id", by.y="short_name", all.x=TRUE)
divvy[,end_station_name:=fcoalesce(divvy[,name],divvy[,end_station_name])]
divvy <- divvy[,-c("station_id","name","lat","lon","capacity")]
divvy <- merge(divvy, station, by.x=c("start_lat","start_lng"), by.y=c("lat","lon"), all.x=TRUE)
divvy[,start_station_name:=fcoalesce(divvy[,start_station_name],divvy[,name])]
divvy[,start_station_id:=fcoalesce(divvy[,start_station_id],divvy[,short_name])]
divvy <- divvy[,-c("station_id","name","short_name","capacity")]
divvy <- merge(divvy, station, by.x=c("end_lat","end_lng"), by.y=c("lat","lon"), all.x=TRUE)
divvy[,end_station_name:=fcoalesce(divvy[,end_station_name],divvy[,name])]
divvy[,end_station_id:=fcoalesce(divvy[,end_station_id],divvy[,short_name])]
divvy <- divvy[,-c("station_id","name","short_name","capacity")]
head(divvy)
# Out:
#   end_lat end_lng start_lat start_lng end_station_id start_station_id
# 1 NA      NA      41.65187  -87.53967 NA             20214
# 2 NA      NA      41.65187  -87.53967 NA             20214
# 3 NA      NA      41.65667  -87.59880 NA             20212
# 4 NA      NA      41.65667  -87.59880 NA             20212
# 5 NA      NA      41.65667  -87.59880 NA             20212
# 6 NA      NA      41.65667  -87.59880 NA             20212
#   ride_id          rideable_type started_at          ended_at
# 1 AFF9DEB0BC836CC9 docked_bike   2022-06-04 07:26:15 2022-06-05 08:26:16
# 2 F105E100709C76A5 docked_bike   2022-09-01 07:57:12 2022-09-02 08:57:13
# 3 A72DD0003D4C1D33 classic_bike  2021-10-21 15:12:06 2021-10-22 16:12:02
# 4 7A93DC0729A8F704 classic_bike  2021-10-26 05:56:26 2021-10-27 06:56:21
# 5 6B7477B18D4A172F classic_bike  2022-04-29 19:43:41 2022-04-30 20:43:37
# 6 0AB7142E6453CBEE classic_bike  2022-05-30 20:47:38 2022-05-31 21:47:33
# ...

# %% [markdown]
# Cek *missing values* pada kolom `station_id` dan `station_name` setelah digabungkan dengan dataset `station information`

# %%
check_missing_value(divvy)
# Out:
#    column_name        missing_value missing_rate_percent
# 1  end_lat              5844         0.10
# 2  end_lng              5844         0.10
# 3  start_lat               0         0.00
# 4  start_lng               0         0.00
# 5  end_station_id     957941        16.44
# 6  start_station_id   895001        15.36
# 7  ride_id                 0         0.00
# 8  rideable_type           0         0.00
# 9  started_at              0         0.00
# 10 ended_at                0         0.00
# 11 start_station_name 895001        15.36
# 12 end_station_name   957941        16.44
# 13 member_casual           0         0.00
# 14 length_trip_s           0         0.00

# %% [markdown]
# *Missing values* pada kolom `station_id` dan `station_name` setelah digabungkan dengan dataset `station information` masih sekitar 15%. Dataset `station information` tidak cukup baik untuk menaikkan *complete_rate* dataset `divvy` pada kolom `start_station_id`, `start_station_name`, `end_station_id`, dan `end_station_name`. Walaupun terdapat variabel `lat` dan `lng` yang memungkinkan untuk memperoleh informasi `station_name`, tetapi variabel tersebut memiliki desimal yang kurang akurat.
#
# Hal ini akan menjadi sedikit batasan dalam analisis ini.

# %% [markdown]
# # Menganalisis

# %% [markdown]
# ### Menambahkan beberapa kolom untuk analisis lebih lanjut

# %%
library("lubridate")
# create day_of_week column
divvy[,day_of_week:=started_at %>% lubridate::wday(,week_start = getOption("lubridate.week.start", 1)) %>%
     factor(levels = 1:7,
            labels = c("Sen", "Sel", "Rab", "Kam", "Jum", "Sab", "Min"))] 
divvy[,month:=started_at %>% month() %>%
     factor(levels = 1:12)]

# Change membership value
divvy[member_casual=="casual",member_casual:="Casual Members"]
divvy[member_casual=="member",member_casual:="Annual Members"]
divvy[rideable_type=="docked_bike",rideable_type:="Docked Bike"]
divvy[rideable_type=="classic_bike",rideable_type:="Classic Bike"]
divvy[rideable_type=="electric_bike",rideable_type:="Electric Bike"]

# add hour started_at column
divvy[,hour:=hour(started_at) %>% factor(level=0:23)]

# Calculate distance from latitude and longitude
if (!require(geosphere)) install.packages("geosphere")
library(geosphere)
divvy[,distance:=distHaversine(divvy[,c("start_lat","start_lng")],
                               divvy[,c("end_lat","end_lng")])]

# %% [markdown]
# ### Setting ggplot library untuk *data visualization*

# %%
# Install "Airbnb" ggplot theme
devtools::install_github("ricardo-bion/ggtech", 
                          dependencies=TRUE)
library(ggtech)

# Plot size function
fig <- function(width, heigth){
     options(repr.plot.width = width, repr.plot.height = heigth)
}
# Out:
# Skipping install of 'ggtech' from a github remote, the SHA1 (4d6282f2) has not changed since last install.
#   Use `force = TRUE` to force installation

# %% [markdown]
# ### Visualisasi Data

# %%
data_plot <- divvy[,c(.N),by=c("day_of_week","member_casual")]
casual_mean <- data_plot[member_casual=="Casual Members",mean(V1)]
member_mean <- data_plot[member_casual=="Annual Members",mean(V1)]

fig(10,7.5)
ggplot(data=data_plot)+
    theme_airbnb_fancy()+
    scale_fill_tech(theme="X23andme")+
    theme(plot.title = element_text(face="bold",colour="#3595d6"),
         plot.subtitle = element_text(colour="#3595d6"))+
    geom_bar(mapping=aes(x=day_of_week, y=V1, fill=member_casual), position="dodge", stat="identity")+
    geom_hline(aes(yintercept=casual_mean),colour="#92c746",linetype="dashed")+
    geom_hline(aes(yintercept=member_mean),colour="#3595d6",linetype="dashed")+
    geom_label(aes(x=1,y=casual_mean+15000, label="Average Casual Members", hjust=0), colour="white", fill="#92c746", fontface="bold")+
    geom_label(aes(x=1,y=member_mean+15000, label="Average Annual Members", hjust=0), colour="white", fill="#3595d6", fontface="bold")+
    labs(x='Hari', y='Total Perjalanan', 
         title='Total Perjalanan per Hari',
         subtitle="dari 01 Oktober 2021 sampai 30 September 2022")+
    scale_y_continuous(breaks = c(150000, 300000, 450000, 600000), labels = c("150K", "300K", "450K", "600K"))
# Out:
# plot without title

# %% [markdown]
# Rata-rata *Annual Members* melakukan perjalanan pada hari kerja (Senin s.d Jumat). Sedangkan rata-rata *Casual Members* melakukan perjalanan untuk santai pada akhir pekan (Sabtu dan Minggu).

# %%
data_plot <- divvy[,c(.N),by=c("month","member_casual")]
casual_mean <- data_plot[member_casual=="Casual Members",mean(V1)]
member_mean <- data_plot[member_casual=="Annual Members",mean(V1)]

fig(10,7.5)
ggplot(data=data_plot)+
    theme_airbnb_fancy()+
    scale_fill_tech(theme="X23andme")+
    theme(plot.title = element_text(face="bold",colour="#3595d6"),
         plot.subtitle = element_text(colour="#3595d6"))+
    geom_bar(mapping=aes(x=month, y=V1, fill=member_casual), position="dodge", stat="identity")+
    geom_hline(aes(yintercept=casual_mean),colour="#92c746",linetype="dashed")+
    geom_hline(aes(yintercept=member_mean),colour="#3595d6",linetype="dashed")+
    geom_label(aes(x=1,y=casual_mean+15000, label="Average Casual Members", hjust=0), colour="white", fill="#92c746", fontface="bold")+
    geom_label(aes(x=1,y=member_mean+15000, label="Average Annual Members", hjust=0), colour="white", fill="#3595d6", fontface="bold")+
    labs(x='Bulan', y='Total Perjalanan', 
         title='Total Perjalanan per Bulan',
         subtitle="dari 01 Oktober 2021 sampai 30 September 2022")+
    scale_y_continuous(breaks = c(100000, 200000, 300000, 400000, 500000), labels = c("100K", "200K", "300K", "400K", "500K"))
# Out:
# plot without title

# %% [markdown]
# Kota Chicago memiliki 4 musim;
# 1. Musim Semi (Maret s.d Mei)
# 2. Musim Panas (Juni s.d Agustus)
# 3. Musim Gugur (September s.d November)
# 4. Musim DIngin (Desember s.d Februari)
#
# Rata-rata pengendara *Annual Members* dan *Casual Members* melakukan perjalanan pada musim panas dan musim gugur. Walaupun tidak menutup kemungkinan mereka melakukan perjalanan diakhir tahun untuk merayakan pergantian tahun.

# %%
data_plot <- divvy[,c(.N),by=c("rideable_type","member_casual")]

fig(10,7.5)
ggplot(data=data_plot)+
    theme_airbnb_fancy()+
    scale_fill_tech(theme="X23andme")+
    theme(plot.title = element_text(face="bold",colour="#3595d6"),
         plot.subtitle = element_text(colour="#3595d6"))+
    geom_bar(mapping=aes(x=rideable_type, y=V1, fill=member_casual), position="dodge", stat="identity")+
    labs(x='Jenis Sepeda', y='Total Perjalanan', 
         title='Total Perjalanan per Jenis Sepeda',
         subtitle="dari 01 Oktober 2021 sampai 30 September 2022")+
    scale_y_continuous(breaks = c(450000, 900000, 1350000, 1800000), labels = c("450K", "900K", "1.35M", "1.8M"))
# Out:
# plot without title

# %% [markdown]
# *Annual Members* lebih memilih menggunakan *Classic Bike*. Sedangkan *Casual Members* lebih memilih *Electric Bike*. Kemungkinan hal ini dikarenakan biaya penyewaan *Classic Bike* dan *Electric Bike* yang lebih terjangkau.

# %%
data_plot <- divvy[,mean(length_trip_s/60),by=c("day_of_week","member_casual")]
casual_mean <- data_plot[member_casual=="Casual Members",mean(V1)]
member_mean <- data_plot[member_casual=="Annual Members",mean(V1)]
mean_diff <- ((casual_mean %>% as.numeric)/(member_mean %>% as.numeric)) %>% round(2)

fig(10,7.5)
ggplot(data=data_plot,mapping=aes(x=day_of_week, y=V1, color=member_casual, group=member_casual))+
    theme_airbnb_fancy()+
    scale_fill_tech(theme="X23andme")+
    theme(plot.title = element_text(face="bold",colour="#3595d6"),
         plot.subtitle = element_text(colour="#3595d6"))+
    geom_line()+
    geom_point()+
    geom_hline(aes(yintercept=casual_mean),colour="#00bfc4",linetype="dashed")+
    geom_hline(aes(yintercept=member_mean),colour="#f8766d",linetype="dashed")+
    geom_label(aes(x=1,y=casual_mean+1, label="Average Casual Members", hjust=0), colour="white", fill="#00bfc4", fontface="bold")+
    geom_label(aes(x=1,y=member_mean+1, label="Average Annual Members", hjust=0), colour="white", fill="#f8766d", fontface="bold")+
    labs(x='Hari', y='Rata-rata Lama Perjalanan (menit)', 
         title='Durasi Perjalanan per Hari',
         subtitle="dari 01 Oktober 2021 sampai 30 September 2022")
# Out:
# Don't know how to automatically pick scale for object of type difftime. Defaulting to continuous.
# plot without title

# %% [markdown]
# *Casual Members* memiliki durasi perjalanan 2.24 kali lebih lama daripada *Annual Members*. Ini menjadi hal yang baik untuk melakukan kampanye yang menargetkan agar *casual members* menjadi *annual members*

# %%
data_plot <- divvy[,mean(length_trip_s/60),by=c("month","member_casual")]
casual_mean <- data_plot[member_casual=="Casual Members",mean(V1)]
member_mean <- data_plot[member_casual=="Annual Members",mean(V1)]
mean_diff <- ((casual_mean %>% as.numeric)/(member_mean %>% as.numeric)) %>% round(2)

fig(10,7.5)
ggplot(data=data_plot,mapping=aes(x=month, y=V1, color=member_casual, group=member_casual))+
    theme_airbnb_fancy()+
    scale_fill_tech(theme="X23andme")+
    theme(plot.title = element_text(face="bold",colour="#3595d6"),
         plot.subtitle = element_text(colour="#3595d6"))+
    geom_line()+
    geom_point()+
    geom_hline(aes(yintercept=casual_mean),colour="#00bfc4",linetype="dashed")+
    geom_hline(aes(yintercept=member_mean),colour="#f8766d",linetype="dashed")+
    geom_label(aes(x=1,y=casual_mean+1, label="Average Casual Members", hjust=0), colour="white", fill="#00bfc4", fontface="bold")+
    geom_label(aes(x=1,y=member_mean+1, label="Average Annual Members", hjust=0), colour="white", fill="#f8766d", fontface="bold")+
    labs(x='Bulan', y='Rata-rata Lama Perjalanan (menit)', 
         title='Durasi Perjalanan per Bulan',
         subtitle="dari 01 Oktober 2021 sampai 30 September 2022")
# Out:
# Don't know how to automatically pick scale for object of type difftime. Defaulting to continuous.
# plot without title

# %% [markdown]
# Durasi perjalanan perbulan dari *casual members* juga selalu lebih tinggi daripada *annual members*. Rata-rata durasi perjalanan per bulan *casual members* lebih lama 2.31 kali daripada *annual members*.
#
# Dilihat dari durasi perjalanan perhari dan perbulan, jika strategi kampanye yang menargetkan *casual members* menjadi *annual members* berhasil akan membawa dampak terhadap revenue perusahaan yang meningakat dalam jangka waktu yang lama.

# %%
data_plot <- divvy[day_of_week=="Sab" | day_of_week=="Min"][
    ,(c(.N)/365) %>% round(0),by=c("member_casual","hour")
]
mean <- data_plot[,mean(V1)]

fig(12,7.5)
ggplot(data=data_plot,mapping=aes(x=hour, y=V1, color=member_casual, group=member_casual))+
    theme_airbnb_fancy()+
    scale_fill_tech(theme="X23andme")+
    theme(plot.title = element_text(face="bold",colour="#3595d6"),
          plot.subtitle = element_text(colour="#3595d6"))+
    geom_line()+
    geom_point()+
    geom_hline(aes(yintercept=mean),colour="#00bfc4",linetype="dashed")+
    annotate("rect", xmin=10, xmax=21, ymin=-Inf, ymax=Inf, alpha=0.1, fill="blue")+
    annotate("text", x=14.5, y=150, label="Waktu\nterbaik", size=7, fontface="bold", color="red")+
    geom_label(aes(x=1,y=mean+1, label="Rata-rata Pengendara", hjust=0), colour="white", fill="#00bfc4", fontface="bold")+
    labs(x='Jam', y='Rata-rata Jumlah Pengendara', 
         title='Rata-rata Jumlah Pengendara per Jam (Akhir Pekan)',
         subtitle="dari 01 Oktober 2021 sampai 30 September 2022")
# Out:
# plot without title

# %% [markdown]
# Jumlah pengendara baik *casual members* maupun *annual members* melebihi rata-rata pada pukul 9 pagi hingga pukul 8 malam. Pada waktu tersebut kemungkinan sebagian besar dari mereka menggunakan waktunya untuk bersantai di akhir pekan. Waktu tersebut adalah waktu terbaik untuk menargetkan kampanye.

# %%
data_plot <- divvy[!(day_of_week=="Sab" | day_of_week=="Min")][
    ,(c(.N)/365) %>% round(0),by=c("member_casual","hour")
]
mean <- data_plot[,mean(V1)]

fig(12,7.5)
ggplot(data=data_plot,mapping=aes(x=hour, y=V1, color=member_casual, group=member_casual))+
    theme_airbnb_fancy()+
    scale_fill_tech(theme="X23andme")+
    theme(plot.title = element_text(face="bold",colour="#3595d6"),
          plot.subtitle = element_text(colour="#3595d6"))+
    geom_line()+
    geom_point()+
    geom_hline(aes(yintercept=mean),colour="#00bfc4",linetype="dashed")+
    annotate("text", x=11, y=750, label="Jam Sibuk", size=7, fontface="bold", color="red")+
    annotate("text", x=13, y=440, label="Makan\nSiang", size=5, fontface="bold", color="red")+
    annotate("curve",x=9, xend=9, y=700, yend=525,
            curvature=0.5, arrow=arrow(length=unit(3,"mm")), color="red")+
    annotate("curve",x=12, xend=17, y=775, yend=800,
            curvature=-0.3, arrow=arrow(length=unit(3,"mm")), color="red")+
    geom_label(aes(x=1,y=mean+1, label="Rata-rata Pengendara", hjust=0), colour="white", fill="#00bfc4", fontface="bold")+
    labs(x='Jam', y='Rata-rata Jumlah Pengendara', 
         title='Rata-rata Jumlah Pengendara per Jam (Hari Kerja)',
         subtitle="dari 01 Oktober 2021 sampai 30 September 2022")
# Out:
# plot without title

# %% [markdown]
# Pada hari kerja, *annual members* terlihat lebih mendominasi pada jam sibuk yaitu pada pukul 8 pagi dan pukul 5 sore. Sedangkan *casual members* terlihat mengalami lonjakan secara signifikan pada pukul 5 sore.
#
# Ini menunjukkan bahwa sebagian besar *annual members* berlangganan sepeda untuk keperluan berangkat dan pulang kerja sehari-hari.

# %%
busiest_station_weekend <- divvy[(day_of_week=="Sab" | day_of_week=="Min") & (!is.na(start_station_name)), 
      c(.N), 
      by=c("member_casual", "start_station_name")][
        member_casual=="Casual Members",c("start_station_name","V1")]
setorder(busiest_station_weekend, -V1)
busiest_station_weekend <- busiest_station_weekend[1:10]

busiest_station_weekday <- divvy[!(day_of_week=="Sab" | day_of_week=="Min") & (!is.na(start_station_name)), 
      c(.N), 
      by=c("member_casual", "start_station_name")][
        member_casual=="Casual Members",c("start_station_name","V1")]
setorder(busiest_station_weekday, -V1)
busiest_station_weekday <- busiest_station_weekday[1:10]

library("forcats")
fig(10,10)
ggplot(data=busiest_station_weekday, aes(y=fct_reorder(start_station_name, V1), x=V1))+
  theme_airbnb_fancy()+
  scale_fill_tech(theme="X23andme")+
  theme(plot.title = element_text(face="bold",colour="#3595d6", hjust=1.6),
        plot.subtitle = element_text(colour="#3595d6", hjust=-2.45))+
  geom_col(fill="#01bfc4")+
  labs(x='Total Casual Members', y='', 
         title='Top 10 Stasiun Tersibuk di Akhir Pekan',
         subtitle="berdasarkan Casual Members")

fig(10,10)
ggplot(data=busiest_station_weekend, aes(y=fct_reorder(start_station_name, V1), x=V1))+
  theme_airbnb_fancy()+
  scale_fill_tech(theme="X23andme")+
  theme(plot.title = element_text(face="bold",colour="#3595d6", hjust=1.6),
        plot.subtitle = element_text(colour="#3595d6", hjust=-2.45))+
  geom_col(fill="#01bfc4")+
  labs(x='Total Casual Members', y='', 
         title='Top 10 Stasiun Tersibuk di Akhir Pekan',
         subtitle="berdasarkan Casual Members")
# Out:
# plot without title
# plot without title

# %% [markdown]
# 8 dari 10 stasiun tersibuk pada hari kerja dan akhir pekan berada pada posisi yang sama. Stasiun tersibuk urutan pertama (Streeter DR & Grand Ave) terlihat berbeda secara signifikan terhadap stasiun lainnya.

# %% [markdown]
# ## *K-Means Clustering*

# %% [markdown]
# Tujuan K-Means Clustering dalam analisis ini untuk melakukan pengelompokkan pengguna sepeda (*casual members*) berdasarkan durasi dan panjang perjalanan yang dilakukan.
#
# Beberapa persyaratan untuk melakukan analisis *K-Means Clustering* di R sebagai berikut.
# 1. Tiap baris adalah pengamatan individu, dan kolom adalah variabel.
# 2. *Missing value* harus dihapus.
# 3. Data harus terstandarisasi agar variabel dapat dibandingkan. Perlu diingat bahwa, proses standarisasi atau *scaling* data merupakan proses transformasi data sehingga data memiliki rata-rata nol dan standar deviasi satu.
#
# *Catatan: meskipun tidak menjadi persyaratan utama, outlier data juga akan dihapus agar hasil cluster lebih optimal*

# %%
# Import library for K-Means Clustering
if (!require(cluster)) install.packages("cluster")
if (!require(factoextra)) install.packages("factoextra")
library(cluster)    # clustering algorithms
library(factoextra) # clustering algorithms & visualization

# %% [markdown]
# ### Persiapan Data untuk *K-Means Clustering*

# %%
data <- divvy[member_casual=="Casual Members", c("length_trip_s","distance")]
# Remove missing value
data <- data %>% na.omit()
# convert to numeric and from second to minutes
data[,length_trip_m := as.numeric(length_trip_s)/60]
data <- data[,c("length_trip_m","distance")]

# Delete outlier
Q <- quantile(data[,length_trip_m], probs=c(.25, .75), na.rm = FALSE)
iqr <- IQR(data[,length_trip_m])
up <-  Q[2]+1.5*iqr # Upper Range  
low<- Q[1]-1.5*iqr # Lower Range
data <- subset(data, data[,length_trip_m] > (Q[1] - 1.5*iqr) & data[,length_trip_m] < (Q[2]+1.5*iqr))

Q <- quantile(data[,distance], probs=c(.25, .75), na.rm = FALSE)
iqr <- IQR(data[,distance])
up <-  Q[2]+1.5*iqr # Upper Range  
low<- Q[1]-1.5*iqr # Lower Range
data <- subset(data, data[,distance] > (Q[1] - 1.5*iqr) & data[,distance] < (Q[2]+1.5*iqr))

# %% [markdown]
# ### Populasi *Casual Members* berdasarkan jarak dan durasi perjalanan.

# %%
if (!require(hexbin)) install.packages("hexbin")
library(hexbin)
fig(8.5,7)
ggplot(data, aes(x=length_trip_m, y=distance))+
  theme_airbnb_fancy()+
  scale_fill_tech(theme="X23andme")+
  theme(plot.title = element_text(face="bold",colour="#3595d6"),
        plot.subtitle = element_text(colour="#3595d6"))+
  stat_binhex(bins = 15)+
  scale_fill_gradient(low = "#00c9eb", high = "#f21146")+
  labs(x='Durasi Perjalanan (menit)', y='Jarak (meter)',
       title='Populasi Casual Members',
       subtitle="Berdasarkan Jarak dan Durasi Perjalanan")
# Out:
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
# plot without title

# %% [markdown]
# Terlihat populasi terbanyak dari *casual members* adalah yang melakukan perjalanan dengan jarak yang pendek dan durasi yang singkat.

# %% [markdown]
# ### Transformasi Data

# %%
data_scale <- scale(data)
head(data_scale)
# Out:
#      length_trip_m distance
# [1,]  3.0546841    -0.04854585
# [2,]  0.8149878    -0.10019000
# [3,]  3.1351806    -0.59156570
# [4,]  1.7383298    -0.66843558
# [5,] -0.5203068    -0.14035431
# [6,]  0.1378703    -1.14008031

# %%
model_kmeans <- kmeans(data_scale, centers = 4, nstart = 25)
data[, cluster:=model_kmeans$cluster]

# %% [markdown]
# ### Kelompok *Casual Members*

# %%
distance_mean <- data[,mean(distance)]
length_trip_mean <- data[,mean(length_trip_m)]

ggplot(data=data, aes(x=distance, y=length_trip_m, colour=cluster))+
  theme_airbnb_fancy()+
  scale_fill_tech(theme="X23andme")+
  theme(plot.title = element_text(face="bold",colour="#3595d6"),
        plot.subtitle = element_text(colour="#3595d6"))+
  geom_point()+
  geom_hline(aes(yintercept=length_trip_mean),colour="red",linetype="dashed")+
  geom_vline(aes(xintercept=distance_mean),colour="red",linetype="dashed")+
  labs(x='Jarak (meter)', y='Durasi Perjalanan (menit)',
       title='Kelompok Casual Members',
       subtitle="dikelompokkan dengan K-Means Clustering",
       colour="Kelompok")
# Out:
# plot without title

# %% [markdown]
# **Kelompok 1** didominasi oleh *casual members* dengan jarak diatas rata-rata dan durasi dibawah rata-rata.
#
# **Kelompok 2** didominasi oleh *casual members* dengan jarak dibawah rata-rata dan durasi diatas rata-rata.
#
# **Kelompok 3** didominasi oleh *casual members* dengan jarak diatas rata-rata dan durasi diatas rata-rata.
#
# **Kelompok 4** didominasi oleh *casual members* dengan jarak dibawah rata-rata dan durasi dibawah rata-rata.
#
# **Kelompok 4** adalah target kampanye terbaik.

# %% [markdown]
# # Berbagi

# %% [markdown]
# # Bertindak

# %% [markdown]
# Berikut beberapa rekomendasi yang dibagi menjadi beberapa aspek berdasarkan temuan utama.
#
# **Aspek Waktu**
#
# 1. Waktu terbaik untuk mencanangkan kampanye adalah pada akhir pekan sekitar pukul 09.00 hingga 20.00.
# 2. Musim panas dan musim gugur adalah musim terbaik untuk melakukan kampanye, yaitu sekitar bulan Mei hingga Oktober.
#
# **Aspek Jenis Sepeda**
#
# Jangan sekali-kali menargetkan promosi pada jenis *Docked Bike*.
#
# **Aspek Tempat**
#
# Lakukan kampanye pada stasiun "Streeter DR & Grand Ave"
#
# **Aspek Jarak dan Durasi**
#
# Lakukan kampanye pada *casual members* yang memiliki perjalanan dengan jarak yang pendek dan durasi yang singkat.
#
# **Aspek Lainnya**
#
# Menambahkan tipe membership diantara *casual members* dan *annual members* mungkin juga akan berpeluang terhadap kenaikan revenue. Misalnya dengan menambahkan tipe membership mingguan atau bulanan yang sedikit lebih murah daripada *casual membership* tetapi lebih mahal daripada *annual membership*. Hal ini akan menargetkan mereka yang terkendala dalam masalah ekonomi untuk berlangganan *annual membership*
